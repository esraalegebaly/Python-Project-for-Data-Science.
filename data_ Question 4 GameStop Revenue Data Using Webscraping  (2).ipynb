# %%
await __import__("piplite").install(**{'requirements': ['yfinance']})
await __import__("piplite").install(**{'requirements': ['pandas']})
await __import__("piplite").install(**{'requirements': ['requests']})
await __import__("piplite").install(**{'requirements': ['lxml']})
await __import__("piplite").install(**{'requirements': ['plotly']})

import yfinance as yf
import pandas as pd
import requests
from lxml import html
import matplotlib.pyplot as plt

def get_stock_data(ticker_symbol, start_date, end_date):
    stock = yf.Ticker(ticker_symbol)
    stock_data = stock.history(start=start_date, end=end_date)
    return stock_data

def get_revenue_data(url):
    response = requests.get(url)
    tree = html.fromstring(response.content)
    
    # Assuming the revenue data is in a table, adjust the XPath accordingly
    revenue_data = tree.xpath('//table[@class="your-revenue-table-class"]/tr[position()>1]/td/text()')
    
    # Reshape data into pairs (date, revenue)
    revenue_data = [revenue_data[i:i+2] for i in range(0, len(revenue_data), 2)]
    
    return pd.DataFrame(revenue_data, columns=["Date", "Revenue"])

# Define the ticker symbol for GameStop and date range
ticker_gamestop = "GME"
start_date = "10/31/2009"
end_date = "08/01/2023"

# Get GameStop stock data
gamestop_stock_data = get_stock_data(ticker_gamestop, start_date, end_date)

# Define the URL for GameStop revenue data
url_gamestop_revenue = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"

# Get GameStop revenue data
gamestop_revenue_data = get_revenue_data(url_gamestop_revenue)

# Plotting
if gamestop_revenue_data is not None:
    fig, ax1 = plt.subplots(figsize=(10, 6))

    color = 'tab:red'
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Stock Closing Price', color=color)
    ax1.plot(gamestop_stock_data.index, gamestop_stock_data['Close'], color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    ax2 = ax1.twinx()
    color = 'tab:blue'
    ax2.set_ylabel('Revenue', color=color)
    ax2.plot(pd.to_datetime(gamestop_revenue_data['Date']), gamestop_revenue_data['Revenue'], color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    plt.title('GameStop Stock and Revenue')
    plt.show()
# Out:
# Failed to get ticker 'GME' reason: Can't connect to HTTPS URL because the SSL module is not available.
# GME: No timezone found, symbol may be delisted
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 42
#      39 url_gamestop_revenue = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
#      41 # Get GameStop revenue data
# ---> 42 gamestop_revenue_data = get_revenue_data(url_gamestop_revenue)
#      44 # Plotting
#      45 if gamestop_revenue_data is not None:
#
# Cell In[9], line 19, in get_revenue_data(url)
#      18 def get_revenue_data(url):
# ---> 19     response = requests.get(url)
#      20     tree = html.fromstring(response.content)
#      22     # Assuming the revenue data is in a table, adjust the XPath accordingly
#
# File /lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /lib/python3.11/site-packages/urllib3/connectionpool.py:769, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     766 try:
#     767     # Request a connection from the queue.
#     768     timeout_obj = self._get_timeout(timeout)
# --> 769     conn = self._get_conn(timeout=pool_timeout)
#     771     conn.timeout = timeout_obj.connect_timeout  # type: ignore[assignment]
#     773     # Is this a closed/new connection that requires CONNECT tunnelling?
#
# File /lib/python3.11/site-packages/urllib3/connectionpool.py:295, in HTTPConnectionPool._get_conn(self, timeout)
#     292     log.debug("Resetting dropped connection: %s", self.host)
#     293     conn.close()
# --> 295 return conn or self._new_conn()
#
# File /lib/python3.11/site-packages/urllib3/connectionpool.py:1060, in HTTPSConnectionPool._new_conn(self)
#    1052 log.debug(
#    1053     "Starting new HTTPS connection (%d): %s:%s",
#    1054     self.num_connections,
#    1055     self.host,
#    1056     self.port or "443",
#    1057 )
#    1059 if not self.ConnectionCls or self.ConnectionCls is DummyConnection:  # type: ignore[comparison-overlap]
# -> 1060     raise ImportError(
#    1061         "Can't connect to HTTPS URL because the SSL module is not available."
#    1062     )
#    1064 actual_host: str = self.host
#    1065 actual_port = self.port
#
# ImportError: Can't connect to HTTPS URL because the SSL module is not available.
